# %%
people = {
    "first": ["xavir", 'Jane', 'John'], 
    "last": ["anik", 'Doe', 'Doe'], 
    "email": ["xaviranik@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df.head()
# Out:
#    first  last                email
# 0  xavir  anik  xaviranik@gmail.com
# 1   Jane   Doe    JaneDoe@email.com
# 2   John   Doe    JohnDoe@email.com

# %%
# Filter Mask
df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = (df['last'] == 'Doe')

# %%
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = ((df['last'] == 'Doe') & (df['first'] == 'John'))
df.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = ((df['last'] == 'Doe') | (df['first'] == 'Jane'))
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
df.loc[~filt, 'email']
# Out:
# 0    xaviranik@gmail.com
# Name: email, dtype: object

# %%
df = pd.read_csv('_datasets/survey_stackoverflow-utf8.csv', index_col = 'Respondent')
schema_df = pd.read_csv('_datasets/survey_stackoverflow_results_schema.csv', index_col = 'Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#             Unnamed: 0                                         MainBranch  \
# Respondent
# 1                    0             I am a student who is learning to code
# 2                    1             I am a student who is learning to code
# 3                    2  I am not primarily a developer, but I write co...
# 4                    3                     I am a developer by profession
# 5                    4                     I am a developer by profession
#
#            Hobbyist                 OpenSourcer  \
# Respondent
# 1               Yes                       Never
# 2                No     Less than once per year
# 3               Yes                       Never
# 4                No                       Never
# 5               Yes  Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelors degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelors degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelors degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           Im not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
# Filtering with country name
countries = ['India', 'Canada', 'United Kingdom', 'Germany', 'Poland']
filt = df['Country'].isin(countries)
df.loc[filt, ['Country', 'DatabaseWorkedWith', 'YearsCode', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 DatabaseWorkedWith  \
# Respondent
# 1           United Kingdom                                             SQLite
# 6                   Canada                                 MongoDB;PostgreSQL
# 8                    India  Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10                   India  Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 12                  Canada                            MySQL;PostgreSQL;SQLite
# ...                    ...                                                ...
# 586                Germany                                       MySQL;SQLite
# 591                  India                       MongoDB;Microsoft SQL Server
# 594                Germany                               MongoDB;MySQL;SQLite
# 596                  India  DynamoDB;Elasticsearch;MongoDB;MySQL;Oracle;Po...
# 597                Germany                                             SQLite
#
#            YearsCode                                 LanguageWorkedWith  \
# Respondent
# 1                  4                    HTML/CSS;Java;JavaScript;Python
# 6                 13                                         Java;R;SQL
# 8                  8  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                12                      C#;Go;JavaScript;Python;R;SQL
# 12                 5   Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# ...              ...                                                ...
# 586                8                                   Java;Python;Ruby
# 591                7                                      C#;JavaScript
# 594               10                HTML/CSS;Java;JavaScript;Kotlin;PHP
# 596               12  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 597               12                     Java;JavaScript;PHP;Python;SQL
#
#             ConvertedComp
# Respondent
# 1                     NaN
# 6                366420.0
# 8                     NaN
# 10                13293.0
# 12                    NaN
# ...                   ...
# 586               68745.0
# 591                   NaN
# 594               48804.0
# 596               22388.0
# 597               90514.0
#
# [166 rows x 5 columns]

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                        HTML/CSS;Java;JavaScript;Python
# 2                                    C++;HTML/CSS;Python
# 3                                               HTML/CSS
# 4                                    C;C++;C#;Python;SQL
# 5            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                              ...
# 597                       Java;JavaScript;PHP;Python;SQL
# 598    Assembly;Bash/Shell/PowerShell;C;C++;C#;HTML/C...
# 599    Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 600    Bash/Shell/PowerShell;HTML/CSS;Java;PHP;Python...
# 601                                     HTML/CSS;PHP;SQL
# Name: LanguageWorkedWith, Length: 599, dtype: object

# %%
# Filtering with specific language of development for a developer
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, '']
# Out:
#             Unnamed: 0                              MainBranch Hobbyist  \
# Respondent
# 1                    0  I am a student who is learning to code      Yes
# 2                    1  I am a student who is learning to code       No
# 4                    3          I am a developer by profession       No
# 5                    4          I am a developer by profession      Yes
# 8                    7             I code primarily as a hobby      Yes
# ...                ...                                     ...      ...
# 592                589          I am a developer by profession      Yes
# 596                593          I am a developer by profession      Yes
# 597                594          I am a developer by profession      Yes
# 598                595          I am a developer by profession      Yes
# 600                597  I am a student who is learning to code      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 4                                Never
# 5           Once a month or more often
# 8              Less than once per year
# ...                                ...
# 592                              Never
# 596            Less than once per year
# 597            Less than once per year
# 598            Less than once per year
# 600         Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# 8           OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 592         OSS is, on average, of LOWER quality than prop...
# 596         OSS is, on average, of HIGHER quality than pro...
# 597         The quality of OSS and closed source software ...
# 598         OSS is, on average, of HIGHER quality than pro...
# 600         OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  \
# Respondent
# 1                      Not employed, and not looking for work
# 2                          Not employed, but looking for work
# 4                                          Employed full-time
# 5                                          Employed full-time
# 8                          Not employed, but looking for work
# ...                                                       ...
# 592         Independent contractor, freelancer, or self-em...
# 596                                        Employed full-time
# 597                                        Employed full-time
# 598                                        Employed full-time
# 600         Independent contractor, freelancer, or self-em...
#
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 4                    United States              No
# 5                          Ukraine              No
# 8                            India             NaN
# ...                            ...             ...
# 592                          Nepal              No
# 596                          India              No
# 597                        Germany              No
# 598                        Denmark              No
# 600                  United States              No
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 4                    Bachelors degree (BA, BS, B.Eng., etc.)
# 5                    Bachelors degree (BA, BS, B.Eng., etc.)
# 8                    Bachelors degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 592         Some college/university study without earning ...
# 596               Masters degree (MA, MS, M.Eng., MBA, etc.)
# 597               Masters degree (MA, MS, M.Eng., MBA, etc.)
# 598         Secondary school (e.g. American high school, G...
# 600                                 Primary/elementary school
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# ...                                                       ...
# 592         Computer science, computer engineering, or sof...
# 596         Computer science, computer engineering, or sof...
# 597         Computer science, computer engineering, or sof...
# 598                                                       NaN
# 600                                                       NaN
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# 8           Taught yourself a new language, framework, or ...
# ...                                                       ...
# 592         Taken an online course in programming or softw...
# 596         Taught yourself a new language, framework, or ...
# 597         Taken an online course in programming or softw...
# 598                                                       NaN
# 600         Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 4               100 to 499 employees
# 5           10,000 or more employees
# 8                                NaN
# ...                              ...
# 592                    2-9 employees
# 596             100 to 499 employees
# 597         10,000 or more employees
# 598               10 to 19 employees
# 600                              NaN
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
# 8              Developer, back-end;Engineer, site reliability         8
# ...                                                       ...       ...
# 592                Database administrator;Developer, back-end         4
# 596         Developer, back-end;Developer, desktop or ente...        12
# 597                     Developer, mobile;Engineering manager        12
# 598         Developer, back-end;Developer, embedded applic...        30
# 600         Data scientist or machine learning specialist;...         4
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 1                  10               NaN                    NaN
# 2                  17               NaN                    NaN
# 4                  16  Less than 1 year         Very satisfied
# 5                  14                 9      Very dissatisfied
# 8                  16               NaN                    NaN
# ...               ...               ...                    ...
# 592                20                 3  Slightly dissatisfied
# 596                18                 6     Slightly satisfied
# 597                15                10         Very satisfied
# 598                10                20     Slightly satisfied
# 600                10               NaN                    NaN
#
#                                         JobSat              MgrIdiot MgrMoney  \
# Respondent
# 1                                          NaN                   NaN      NaN
# 2                                          NaN                   NaN      NaN
# 4                           Slightly satisfied        Very confident       No
# 5                        Slightly dissatisfied    Somewhat confident      Yes
# 8                                          NaN                   NaN      NaN
# ...                                        ...                   ...      ...
# 592                          Very dissatisfied                   NaN      NaN
# 596                         Slightly satisfied        Very confident       No
# 597                             Very satisfied                   NaN      NaN
# 598         Neither satisfied nor dissatisfied  Not at all confident       No
# 600                                        NaN                   NaN      NaN
#
#              MgrWant                                            JobSeek  \
# Respondent
# 1                NaN                                                NaN
# 2                NaN                    I am actively looking for a job
# 4           Not sure       I am not interested in new job opportunities
# 5                 No       I am not interested in new job opportunities
# 8                NaN                                                NaN
# ...              ...                                                ...
# 592              NaN  Im not actively looking, but I am open to new...
# 596         Not sure  Im not actively looking, but I am open to new...
# 597              NaN  Im not actively looking, but I am open to new...
# 598               No                    I am actively looking for a job
# 600              NaN  Im not actively looking, but I am open to new...
#
#                      LastHireDate  \
# Respondent
# 1                             NaN
# 2            I've never had a job
# 4            Less than a year ago
# 5            Less than a year ago
# 8                             NaN
# ...                           ...
# 592                 1-2 years ago
# 596                 3-4 years ago
# 597         More than 4 years ago
# 598                 1-2 years ago
# 600          I've never had a job
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
# 8                                                         NaN      NaN
# ...                                                       ...      ...
# 592         Complete a take-home project;Interview with pe...       No
# 596         Write any code;Write code by hand (e.g., on a ...       No
# 597         Write any code;Interview with people in peer r...       No
# 598         Write any code;Complete a take-home project;So...       No
# 600                                                       NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
# 8                                                         NaN
# ...                                                       ...
# 592         Languages, frameworks, and other technologies ...
# 596         Languages, frameworks, and other technologies ...
# 597         Office environment or company culture;Opportun...
# 598         Languages, frameworks, and other technologies ...
# 600         Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
# 8                                                         NaN            NaN
# ...                                                       ...            ...
# 592         I heard about a job opportunity (from a recrui...            NPR
# 596         I had a negative experience or interaction at ...            INR
# 597         I heard about a job opportunity (from a recrui...            EUR
# 598                          I was preparing for a job search            DKK
# 600         Something else changed (education, award, medi...            NaN
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
# 8                            NaN        NaN      NaN            NaN
# ...                          ...        ...      ...            ...
# 592               Nepalese rupee        NaN  Monthly            NaN
# 596                 Indian rupee  1600000.0   Yearly        22388.0
# 597                European Euro    79000.0   Yearly        90514.0
# 598                 Danish krone    35000.0  Monthly        64452.0
# 600                          NaN        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
# 8                   NaN                                                NaN
# ...                 ...                                                ...
# 592                48.0  There is a schedule and/or spec (made by me or...
# 596                40.0  There is a schedule and/or spec (made by me or...
# 597                40.0  There is a schedule and/or spec (made by me or...
# 598                37.0  There is a schedule and/or spec (made by me or...
# 600                 NaN                                                NaN
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
# 8                                                         NaN
# ...                                                       ...
# 592         Inadequate access to necessary tools;Lack of s...
# 596         Distracting work environment;Lack of support f...
# 597                        Not enough people for the workload
# 598                                      Time spent commuting
# 600                                                       NaN
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 1                                                         NaN     NaN
# 2                                                         NaN     NaN
# 4                            Less than once per month / Never    Home
# 5                                       A few days each month  Office
# 8                                                         NaN     NaN
# ...                                                       ...     ...
# 592                          Less than once per month / Never  Office
# 596                                     A few days each month  Office
# 597                                       About half the time  Office
# 598         Less than half the time, but at least one day ...    Home
# 600                                                       NaN     NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 4           A little below average                                       No
# 5           A little above average  Yes, because I see value in code review
# 8                              NaN                                      NaN
# ...                            ...                                      ...
# 592                        Average         Yes, because I was told to do so
# 596              Far above average  Yes, because I see value in code review
# 597                        Average  Yes, because I see value in code review
# 598              Far above average  Yes, because I see value in code review
# 600                            NaN                                      NaN
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 4                  NaN                          No, but I think we should
# 5                  NaN                      Yes, it's part of our process
# 8                  NaN                                                NaN
# ...                ...                                                ...
# 592                2.0                                                NaN
# 596                2.0  Yes, it's not part of our process but the deve...
# 597                2.0  Yes, it's not part of our process but the deve...
# 598                6.0                          No, but I think we should
# 600                NaN                                                NaN
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
# 8                                                         NaN
# ...                                                       ...
# 592                                                       NaN
# 596         Developers and management have nearly equal in...
# 597         The CTO, CIO, or other management purchase new...
# 598         Developers and management have nearly equal in...
# 600                                                       NaN
#
#                                 PurchaseWhat  \
# Respondent
# 1                                        NaN
# 2                                        NaN
# 4              I have little or no influence
# 5              I have little or no influence
# 8                                        NaN
# ...                                      ...
# 592                                      NaN
# 596                    I have some influence
# 597            I have little or no influence
# 598         I have a great deal of influence
# 600                                      NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 2                                         C++;HTML/CSS;Python
# 4                                         C;C++;C#;Python;SQL
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                       ...
# 592                             C;C++;HTML/CSS;PHP;Python;SQL
# 596         Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 597                            Java;JavaScript;PHP;Python;SQL
# 598         Assembly;Bash/Shell/PowerShell;C;C++;C#;HTML/C...
# 600         Bash/Shell/PowerShell;HTML/CSS;Java;PHP;Python...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1             C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                                 C++;HTML/CSS;JavaScript;SQL
# 4                                         C;C#;JavaScript;SQL
# 5                    HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# ...                                                       ...
# 592                                       HTML/CSS;Python;SQL
# 596         Bash/Shell/PowerShell;Elixir;Erlang;Go;HTML/CS...
# 597                            Dart;Go;Java;Kotlin;Python;SQL
# 598         Assembly;Bash/Shell/PowerShell;C;C++;C#;HTML/C...
# 600         Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1                                                      SQLite
# 2                                                         NaN
# 4                                                MySQL;SQLite
# 5            Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# ...                                                       ...
# 592                    Elasticsearch;MongoDB;MySQL;PostgreSQL
# 596         DynamoDB;Elasticsearch;MongoDB;MySQL;Oracle;Po...
# 597                                                    SQLite
# 598         DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQ...
# 600                                   MySQL;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# ...                                                       ...
# 592           Elasticsearch;Firebase;MongoDB;PostgreSQL;Redis
# 596         DynamoDB;Elasticsearch;MongoDB;MySQL;Oracle;Po...
# 597                                                    SQLite
# 598                                 Elasticsearch;MySQL;Redis
# 600                                   MySQL;PostgreSQL;SQLite
#
#                                            PlatformWorkedWith  \
# Respondent
# 1                                               MacOS;Windows
# 2                                                     Windows
# 4                                               Linux;Windows
# 5                           Android;Linux;MacOS;Slack;Windows
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# ...                                                       ...
# 592                                       AWS;Linux;WordPress
# 596                               AWS;Docker;Kubernetes;Linux
# 597                                                   Android
# 598         Android;Arduino;AWS;iOS;Linux;Slack;Windows;Wo...
# 600                                Linux;Raspberry Pi;Windows
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1                                     Android;Arduino;Windows
# 2                                                     Windows
# 4                                               Linux;Windows
# 5                       Android;Docker;Kubernetes;Linux;Slack
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# ...                                                       ...
# 592                                         Android;AWS;Linux
# 596         Android;AWS;Docker;Google Cloud Platform;iOS;K...
# 597                                               Android;iOS
# 598         Android;Arduino;AWS;Docker;iOS;Linux;MacOS;Sla...
# 600                Android;AWS;iOS;Linux;Raspberry Pi;Windows
#
#                                            WebFrameWorkedWith  \
# Respondent
# 1                                                Django;Flask
# 2                                                      Django
# 4                                                         NaN
# 5                 Django;Express;Flask;jQuery;React.js;Spring
# 8                               Express;Flask;React.js;Spring
# ...                                                       ...
# 592                                                    Django
# 596         Angular/Angular.js;Django;Flask;jQuery;React.j...
# 597                                                       NaN
# 598         Angular/Angular.js;Drupal;jQuery;Laravel;React...
# 600                                                       NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 1                                                Flask;jQuery
# 2                                                      Django
# 4                                                         NaN
# 5                                Flask;jQuery;React.js;Spring
# 8                        Django;Express;Flask;React.js;Vue.js
# ...                                                       ...
# 592                                   Django;Laravel;React.js
# 596         Angular/Angular.js;Django;Flask;jQuery;React.j...
# 597                                                  React.js
# 598                                     jQuery;Laravel;Vue.js
# 600                              ASP.NET;Django;jQuery;Vue.js
#
#                                            MiscTechWorkedWith  \
# Respondent
# 1                                                     Node.js
# 2                                                         NaN
# 4                                                        .NET
# 5                                             Cordova;Node.js
# 8                                       Hadoop;Node.js;Pandas
# ...                                                       ...
# 592                                                       NaN
# 596                                Chef;Node.js;Pandas;Puppet
# 597                                                       NaN
# 598         Ansible;Chef;Cordova;Node.js;React Native;Tens...
# 600                                                   Node.js
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 1                                                     Node.js
# 2                                                         NaN
# 4                                                        .NET
# 5                    Apache Spark;Hadoop;Node.js;React Native
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# ...                                                       ...
# 592                         Flutter;Hadoop;Node.js;TensorFlow
# 596         Ansible;Chef;Hadoop;Node.js;Pandas;Puppet;Tens...
# 597         Flutter;React Native;TensorFlow;Torch/PyTorch;...
# 598                          React Native;TensorFlow;Unity 3D
# 600                            Node.js;Torch/PyTorch;Unity 3D
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 1                                  IntelliJ;Notepad++;PyCharm      Windows
# 2                                                Atom;PyCharm      Windows
# 4                Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                      IntelliJ;Notepad++;Vim  Linux-based
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# ...                                                       ...          ...
# 592                           Sublime Text;Visual Studio Code  Linux-based
# 596         Android Studio;IntelliJ;PyCharm;Sublime Text;V...  Linux-based
# 597                                       Android Studio;Atom        MacOS
# 598                 Android Studio;Sublime Text;Visual Studio      Windows
# 600                      Notepad++;PyCharm;Visual Studio Code  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 1                                     I do not use containers           NaN
# 2                                     I do not use containers           NaN
# 4                                     I do not use containers    Not at all
# 5                      Outside of work, for personal projects    Not at all
# 8           Development;Testing;Production;Outside of work...           NaN
# ...                                                       ...           ...
# 592                                   I do not use containers           NaN
# 596         Development;Testing;Production;Outside of work...           NaN
# 597                                   I do not use containers           NaN
# 598         Development;Outside of work, for personal proj...    Not at all
# 600                    Outside of work, for personal projects           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
# 8           Useful across many domains and could change ma...        Yes
# ...                                                       ...        ...
# 592         Useful across many domains and could change ma...        Yes
# 596                                                       NaN        Yes
# 597         Useful for decentralized currency (i.e., Bitcoin)        Yes
# 598                                                       NaN         No
# 600         Useful across many domains and could change ma...        Yes
#
#                                             ITperson  OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title    Yes     Twitter
# 2                                                Yes    Yes   Instagram
# 4                                               SIGH    Yes      Reddit
# 5                                           Also Yes    Yes    Facebook
# 8                                               SIGH    Yes     YouTube
# ...                                              ...    ...         ...
# 592                                              Yes    Yes     YouTube
# 596                                         Also Yes    Yes    Facebook
# 597                                              Yes    Yes      Reddit
# 598                                              Yes    Yes     YouTube
# 600                                             SIGH  What?     YouTube
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
# 8           In real life (in person)     Handle              2012
# ...                              ...        ...               ...
# 592         In real life (in person)   Username              2016
# 596         In real life (in person)     Handle              2013
# 597                          Neither   Username              2011
# 598         In real life (in person)   Username              2008
# 600         In real life (in person)   Username              2015
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 4                     Daily or almost daily
# 5                    Multiple times per day
# 8                      A few times per week
# ...                                     ...
# 592                  Multiple times per day
# 596                  Multiple times per day
# 597                   Daily or almost daily
# 598                  Multiple times per day
# 600                    A few times per week
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
# 8           Find answers to specific questions;Learn how t...
# ...                                                       ...
# 592         Find answers to specific questions;Learn how t...
# 596         Find answers to specific questions;Learn how t...
# 597         Find answers to specific questions;Contribute ...
# 598         Find answers to specific questions;Contribute ...
# 600         Find answers to specific questions;Get a sense...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 1                    3-5 times per week      Stack Overflow was much faster
# 2                    3-5 times per week      Stack Overflow was much faster
# 4                    1-2 times per week      Stack Overflow was much faster
# 5           More than 10 times per week      Stack Overflow was much faster
# 8               Less than once per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 592                  3-5 times per week            They were about the same
# 596         More than 10 times per week      Stack Overflow was much faster
# 597                 6-10 times per week      Stack Overflow was much faster
# 598         More than 10 times per week      Stack Overflow was much faster
# 600                  1-2 times per week            They were about the same
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
# 8           11-30 minutes       Yes  Less than once per month or monthly
# ...                   ...       ...                                  ...
# 592                   NaN       Yes  Less than once per month or monthly
# 596          0-10 minutes       Yes      A few times per month or weekly
# 597         31-60 minutes       Yes      A few times per month or weekly
# 598         31-60 minutes       Yes  Less than once per month or monthly
# 600                   NaN        No                                  NaN
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
# 8                                                         Yes
# ...                                                       ...
# 592                                                       Yes
# 596                                                       Yes
# 597                                                       Yes
# 598                                                       Yes
# 600         No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
# 8                         No, and I don't know what those are
# ...                                                       ...
# 592                       No, and I don't know what those are
# 596         No, I've heard of them, but I am not part of a...
# 597         No, I've heard of them, but I am not part of a...
# 598                       No, and I don't know what those are
# 600                       No, and I don't know what those are
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
# 8           Yes, definitely    A lot more welcome now than last year
# ...                     ...                                      ...
# 592                Not sure  Just as welcome now as I felt last year
# 596         Yes, definitely  Just as welcome now as I felt last year
# 597           Yes, somewhat  Just as welcome now as I felt last year
# 598           Yes, somewhat  Just as welcome now as I felt last year
# 600          No, not at all  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# 8           Tech articles written by other developers;Indu...  24.0    Man
# ...                                                       ...   ...    ...
# 592         Tech articles written by other developers;Indu...  29.0    Man
# 596         Tech articles written by other developers;Indu...   NaN    Man
# 597         Tech meetups or events in your area;Courses on...  34.0    Man
# 598         Tech articles written by other developers;Cour...  41.0    Man
# 600         Tech articles written by other developers;Indu...  15.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
# 8             No  Straight / Heterosexual
# ...          ...                      ...
# 592           No  Straight / Heterosexual
# 596           No                      NaN
# 597           No  Straight / Heterosexual
# 598           No  Straight / Heterosexual
# 600           No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
# 8                                                NaN        NaN
# ...                                              ...        ...
# 592                                      South Asian         No
# 596                                      South Asian        Yes
# 597                                      South Asian         No
# 598                     White or of European descent        Yes
# 600                     White or of European descent         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 8           Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 592         Appropriate in length  Neither easy nor difficult
# 596                      Too long  Neither easy nor difficult
# 597         Appropriate in length                        Easy
# 598         Appropriate in length                        Easy
# 600         Appropriate in length                        Easy
#
# [272 rows x 85 columns]
